# %% [markdown]
# <a href="https://colab.research.google.com/github/bhagyasurendran/LGM-Data-Science-Internship/blob/main/Task1_Irisflowerml_prjct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lets Grow More VIRTUAL INTERNSHIP PROGRAM**
#
# **Task 1**
#
# **NAME : BHAGYA S**
#
# **DATA SCIENCE INTERNSHIP**
#
# **Iris Flowers Classification ML Project**
#
# **DESCRIPTION TO TASK** : This particular ML project is usually referred to as the “Hello World” of Machine Learning. The iris flowers dataset contains numeric attributes, and it is perfect for beginners to learn about supervised ML algorithms, mainly how to load and handle data. Also, since this is a small dataset, it can easily fit in memory without requiring special transformations or scaling capabilities.
#
# Dataset:http://archive.ics.uci.edu/ml/datasets/Iris

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sklearn

# %%
column=['Sepal_length','Sepal_width','petal_length','petal_width','species']
data=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",names=column)
data.head()
# Out:
#    Sepal_length  Sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data.tail()
# Out:
#      Sepal_length  Sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
data.describe()
# Out:
#        Sepal_length  Sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal_length  150 non-null    float64
#  1   Sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.shape
# Out:
# (150, 5)

# %%
data.isnull()
# Out:
#      Sepal_length  Sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
data.dtypes
# Out:
# Sepal_length    float64
# Sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
data.count
# Out:
# <bound method DataFrame.count of      Sepal_length  Sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
data.columns
# Out:
# Index(['Sepal_length', 'Sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
pd.DataFrame(data)
# Out:
#      Sepal_length  Sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.nunique()
# Out:
# Sepal_length    35
# Sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %%
unique = data.species.unique().tolist() 
unique
# Out:
# ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

# %%
species_count = data.species.value_counts()
count = species_count.tolist()
species_count.to_frame()
# Out:
#                  species
# Iris-versicolor       50
# Iris-setosa           50
# Iris-virginica        50

# %%
data.species.value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
data.max()
# Out:
# Sepal_length               7.9
# Sepal_width                4.4
# petal_length               6.9
# petal_width                2.5
# species         Iris-virginica
# dtype: object

# %%
data.min()
# Out:
# Sepal_length            4.3
# Sepal_width               2
# petal_length              1
# petal_width             0.1
# species         Iris-setosa
# dtype: object

# %% [markdown]
# **PLOTTING THE DATA**

# %%
plt.pie(count,labels=unique,labeldistance=1,wedgeprops={'linewidth':5,'edgecolor':'white'},autopct="%.02f%%")
plt.title("Number of species with their count",fontsize=20)
plt.show()

# %%
plt.subplots(figsize=(7,7))
sns.scatterplot(x='Sepal_length',y='Sepal_width',data=data,hue='species');
plt.show()

# %%
plt.subplots(figsize=(7,7))
sns.scatterplot(x='petal_length',y='petal_width',data=data,hue='species');
plt.show()

# %%
plot=sns.pairplot(data,hue='species',diag_kind='hist')
plot.fig.suptitle("Relation Of All Features With Each Other",y=1.2,fontsize=20)
plt.show()

# %%
data.hist(figsize=(8,7),color='green',edgecolor='black');
plt.show()

# %% [markdown]
# **DATA PREPROCESSING**

# %%
from sklearn import preprocessing

# %%
X=data.iloc[:,0:4]
X.head()
# Out:
#    Sepal_length  Sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
Y=data['species']
Y=Y.values
Y[0:5]
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa'], dtype=object)

# %%
std=preprocessing.StandardScaler()
X=std.fit_transform(X)
X[0:5]
# Out:
# array([[-0.90068117,  1.03205722, -1.3412724 , -1.31297673],
#        [-1.14301691, -0.1249576 , -1.3412724 , -1.31297673],
#        [-1.38535265,  0.33784833, -1.39813811, -1.31297673],
#        [-1.50652052,  0.10644536, -1.2844067 , -1.31297673],
#        [-1.02184904,  1.26346019, -1.3412724 , -1.31297673]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
X_test.shape
# Out:
# (45, 4)

# %%
X_train.shape
# Out:
# (105, 4)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
lr=LogisticRegression()
knn=KNeighborsClassifier()
dt=DecisionTreeClassifier()

# %%
models=[lr,knn,dt]
scores=[]

# %%
for model in models:
  model.fit(X_train,Y_train)  #LogisticRegresssion.fit(X_train,Y_train) #Fitting Support Vector Classifier to the Training set
  Y_pred=model.predict(X_test) #LogisticRegresssion.predict(X_test) #predicting one test set results 
  scores.append(accuracy_score(Y_test,Y_pred)) #Accuracy on the Test set results
  print("\n\nAccuracy of" + type(model).__name__+"is",accuracy_score(Y_test,Y_pred))
  print("\nclassification Report:\n",classification_report(Y_test,Y_pred))
# Out:
# Accuracy ofLogisticRegressionis 0.9555555555555556
#
# classification Report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       0.94      0.94      0.94        18
#  Iris-virginica       0.92      0.92      0.92        13
#
#        accuracy                           0.96        45
#       macro avg       0.96      0.96      0.96        45
#    weighted avg       0.96      0.96      0.96        45
#
#
#
# Accuracy ofKNeighborsClassifieris 0.9555555555555556
#
# classification Report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       0.94      0.94      0.94        18
#  Iris-virginica       0.92      0.92      0.92        13
#
#        accuracy                           0.96        45
#       macro avg       0.96      0.96      0.96        45
# ...

# %%
results = pd.DataFrame({'Models':['Logistic Regression','K-Nearest Neighbors','Decision Tree'],'Accuracy':scores})

results=results.sort_values(by='Accuracy',ascending=False)
print(results)
# Out:
#                 Models  Accuracy
# 0  Logistic Regression  0.955556
# 1  K-Nearest Neighbors  0.955556
# 2        Decision Tree  0.955556

# %% [markdown]
# **THANK YOU**
